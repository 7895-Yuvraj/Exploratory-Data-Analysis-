# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Importing the req. libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Loading the Data
df=pd.read_csv('C:\\Users\\dell\\Music\\tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
#step--1--Find Continues & Discriptive variable

# %%
con=['total_bill','tip']
dis=['sex','smoker','day','time','size']

# %%
#step--2--Find missing values in Continues & Discriptive variable , if there do the needfull --df.isnull().sum()--EDA PART THEN

# %%
df[con].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
# dtypes: float64(2)
# memory usage: 3.9 KB

# %%
#checking for missing value
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df[con].describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %%
df[dis].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sex     244 non-null    object
#  1   smoker  244 non-null    object
#  2   day     244 non-null    object
#  3   time    244 non-null    object
#  4   size    244 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 9.7+ KB

# %%
df[dis].describe()
# Out:
#              size
# count  244.000000
# mean     2.569672
# std      0.951100
# min      1.000000
# 25%      2.000000
# 50%      2.000000
# 75%      3.000000
# max      6.000000

# %% [markdown]
# ##### step--3--value counts for getting insights of descriptive

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %% [markdown]
# # Plot's for Continous Data

# %% [markdown]
# ##### Univarient (Single Variable)
# ###### 1. Histogram
# ###### 2. Boxplot
# ##### Bivarient (Plot between two variable)
# ###### 1. Scatter plot
# ###### 2. Line plot
# ###### 3. Joint plot
# ###### 4. Violin plot
# ##### Multivarient (More than 2 variable)
# ###### 1. Pair plot
# ###### 2. HeatMap

# %% [markdown]
# ### Histogram

# %%
sns.displot(df['total_bill'],bins=10,kde=True)
plt.show()

# %% [markdown]
# ## Boxplot

# %%
#Boxplot
sns.boxplot(y=df['tip'])
plt.show()

# %% [markdown]
# # Scatter plot

# %%
sns.scatterplot(x=df['total_bill'],y=df['tip'])
plt.show()

# %%
sns.scatterplot(x=df['total_bill'],y=df['tip'],data=df,hue='sex')
plt.show()

# %%
sns.scatterplot(x=df['total_bill'],y=df['tip'],data=df,hue='sex',style='smoker')
plt.show()

# %%
sns.relplot(x=df['total_bill'],y=df['tip'],data=df,hue='sex',col='size',col_wrap=2)
plt.show()

# %%
sns.relplot(x=df['total_bill'],y=df['tip'],data=df,kind='line')
plt.show()

# %%
df['sno']=pd.DataFrame(np.arange(1,245))
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  sno
# 0         16.99  1.01  Female     No   Sun  Dinner     2    1
# 1         10.34  1.66    Male     No   Sun  Dinner     3    2
# 2         21.01  3.50    Male     No   Sun  Dinner     3    3
# 3         23.68  3.31    Male     No   Sun  Dinner     2    4
# 4         24.59  3.61  Female     No   Sun  Dinner     4    5
# ..          ...   ...     ...    ...   ...     ...   ...  ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  240
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  241
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  242
# 242       17.82  1.75    Male     No   Sat  Dinner     2  243
# 243       18.78  3.00  Female     No  Thur  Dinner     2  244
#
# [244 rows x 8 columns]

# %% [markdown]
# ## Line plot

# %%
sns.relplot(x=df['sno'],y=df['tip'],kind='line')
plt.show()

# %% [markdown]
# # Join plot
# ##### We can use the jointplot () function to plot two variables in Seaborn. To create the joint plot, we must create a data frame of the given data using the pandas library or numpy and pass it to the jointplot () function using the data argument.

# %%
sns.jointplot(x=df['total_bill'],y=df['tip'],data=df)
plt.show()

# %% [markdown]
# # Violin Plot
# ##### Violin Plot in Seaborn is used to draw a combination of boxplot and kernel density estimate.

# %%
sns.violinplot(x='total_bill',y='day',data=df)
plt.show()

# %% [markdown]
# # Pair plot
# ##### The pairplot () function of seaborn helps in creating an axes grid through which each numeric variable present in data is shared across y-axes in the form of rows and across x-axes in form of a column.

# %%
sns.pairplot(df,vars=con)
plt.show()

# %% [markdown]
# # Heat Map
# ##### Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix. In this, to represent more common values or higher activities brighter colors basically reddish colors are used and to represent less common or activity values, darker colors are preferred. Heatmap is also defined by the name of the shading matrix. Heatmaps in Seaborn can be plotted by using the seaborn.heatmap() function.

# %% [markdown]
# #### Heatmap for correlation

# %%
c=df[['total_bill','tip']].corr()
c
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
sns.heatmap(c,annot=True)
plt.show()

# %% [markdown]
# ### Plot's for Discrete Data
# ##### 1. Pie pot
# ##### 2. Bar plot
# ##### 3. Count plot
# ### Bivariant
# ##### 1. Boxplot-One discrete & one continous variabe

# %% [markdown]
# ## Countplot

# %%
sns.countplot(x=df['smoker'])
plt.show()

# %%
sns.countplot(x='smoker',data=df)
plt.show()

# %% [markdown]
# #### Barplot

# %%
sns.catplot(x='sex',y='total_bill',data=df,kind='bar')
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=df,hue='size',kind='bar')
plt.show()

# %%
sns.catplot(x='smoker',y='tip',data=df,hue='size',kind='bar')
plt.show()

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(x='day',y='total_bill',data=df)
plt.show()

# %%
sns.boxplot(x='day',y='total_bill',data=df,hue='smoker')
plt.show()
